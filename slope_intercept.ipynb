# %% [markdown]
# <a href="https://colab.research.google.com/github/arcy405/algebraWithPython/blob/main/slope_intercept.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

slope = (y2-y1) / (x2-x1)
print("Slope = ", slope)
# Out:
# Slope =  3.0

# %% [markdown]
# Next, developing equations...

# %%
x1 = 1
y1 = 7
x2 = 2
y2 = 10

# The slope is "m"
m = (y2-y1) / (x2-x1)

# The y intercept is "b"
b = y1 - m*x1

# The full equation
print("y =", m, "x +",b)
# Out:
# y = 3.0 x + 4.0

# %% [markdown]
# Also, display the graph

# %%
import matplotlib.pyplot as plt

x1 = 1
y1 = 7
x2 = 2
y2 = 10

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = -10
xmax = 10
ymin = -10
ymax = 10

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y= 3.0 x + 4.0

# %% [markdown]
# population trend problem 2010 - 55000 popn, 2012 - 76000, find in 2016

# %%
import matplotlib.pyplot as plt

x1 = 0
y1 = 55
x2 = 2
y2 = 76

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = 0
xmax = 10
ymin = 0
ymax = 150

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arrange(xmin, xmax, 2))
#ax.set_yticks(np.arrange(ymin, ymax, 2))

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
print(m*6+b)
plt.show()
# Out:
# y= 10.5 x + 55.0
# 118.0

# %% [markdown]
# people afflicted with common cold drops steadly be 50 each year. It is 875 in 2004 untill 2010
#
# Find year with no cases

# %%
import matplotlib.pyplot as plt

x1 = 0
y1 = 875
x2 = 1
y2 = 825

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = 0
xmax = 18
ymin = 0
ymax = 900

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("cases of flu")
ax.grid(True)
#ax.set_xticks(np.arrange(xmin, xmax, 2))
#ax.set_yticks(np.arrange(ymin, ymax, 2))

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
print(m*6+b)
plt.show()
# Out:
# y= -50.0 x + 875.0
# 575.0

# %%
# solve it with equation
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# put the equation here
eq = 875 - 50*x

solution = solve(eq,x)
print("x = ", solution[0])
# Out:
# x =  35/2

# %% [markdown]
# (year, profit) two points (5,10000) (25, 4000) where x represents year since 1980 and y in thousands of dollars

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = 5
y1 = 10
x2 = 25
y2 = 4

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = 0
xmax = 50
ymin = 0
ymax = 15

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("profit")
ax.grid(True)
ax.set_xticks(np.arange(xmin, xmax, 2))
ax.set_yticks(np.arange(ymin, ymax, 1))

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
print(m*6+b)
plt.show()
# Out:
# y= -0.3 x + 11.5
# 9.7

# %% [markdown]
# in 2004 school popn was 1700 by 2012 popn grown to 2500

# %%
import matplotlib.pyplot as plt

x1 = 0
y1 = 1700
x2 = 8
y2 = 2500

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = 0
xmax = 10
ymin = 0
ymax = 3000

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# Add details to the graph
ax.set_xlabel("time")
ax.set_ylabel("population")
ax.grid(True)
#ax.set_xticks(np.arrange(xmin, xmax, 2))
#ax.set_yticks(np.arrange(ymin, ymax, 2))

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')
print(m*6+b)
plt.show()
# Out:
# y= 100.0 x + 1700.0
# 2300.0

# %% [markdown]
# G garbage tons per week P population thousands
# G = f(p)
# P = 40000 G = 13 tons

# %%
import matplotlib.pyplot as plt

x1 = 0
y1 = 0
x2 = 40
y2 = 13

# Develop the equation y = mx + b
m = (y2-y1)/(x2-x1)
b = y1 - m*x1
print("y=", m, "x +", b)

# For the graph
xmin = 0
xmax = 100
ymin = 0
ymax = 50

# For the line on the graph
y3 = m*xmin + b
y4 = m*xmax + b

# Basic setup for the graph
fig, ax = plt.subplots()
plt.axis([xmin,xmax,ymin,ymax]) # window size
plt.plot([xmin,xmax],[0,0],'b') # blue x axis
plt.plot([0,0],[ymin,ymax],'b') # blue y axis

# Add details to the graph
ax.set_xlabel("thousands")
ax.set_ylabel("tons")
ax.grid(True)
#ax.set_xticks(np.arrange(xmin, xmax, 2))
#ax.set_yticks(np.arrange(ymin, ymax, 2))

# plot the linear function as a red line
plt.plot([xmin,xmax],[y3,y4],'r')

plt.show()
# Out:
# y= 0.325 x + 0.0

# %% [markdown]
# parabola problem

# %%
# solve it with equation
import sympy
from sympy import symbols
from sympy.solvers import solve

x = symbols('x')

# put the equation here
# eq = -16*x**2 + 96*x
eq = 10*x - 1000

solution = solve(eq,x)
print("x = ", solution)

# print(-16*3**2 + 96*3) #6/2
# # domain[0,6] range[0,144]
# Out:
# x =  [100]
